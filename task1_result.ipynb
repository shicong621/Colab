# %% [markdown]
# <a href="https://colab.research.google.com/github/shicong621/Colab/blob/main/task1_result.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Class Challenge: Image Classification of COVID-19 X-rays
# # Task 1 [Total points: 30]

# %% [markdown]
# ## Setup
#
# * This assignment involves the following packages: 'matplotlib', 'numpy', and 'sklearn'.
#
# * If you are using conda, use the following commands to install the above packages:<br>
# ```shell
# conda install matplotlib
# conda install numpy
# conda install -c anaconda scikit-learn
# ```
#
# * If you are using pip, use use the following commands to install the above packages: <br>
# ```shell
# pip install matplotlib
# pip install numpy
# pip install sklearn
# ```

# %% [markdown]
# ## Data
#
# Please download the data using the following link: [COVID-19](https://drive.google.com/file/d/1Y88tgqpQ1Pjko_7rntcPowOJs_QNOrJ-/view).
#
# * After downloading 'Covid_Data_GradientCrescent.zip', unzip the file and you should see the following data structure:
#
#
# |--all<br>
# |--------train<br>
# |--------test<br>
# |--two<br>
# |--------train<br>
# |--------test<br>
#
#
# * Put the 'all' folder, the 'two' folder and this python notebook in the **same directory** so that the following code can correctly locate the data.

# %% [markdown]
# ## [20 points] Binary Classification: COVID-19 vs. Normal

# %%
import os

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report

os.environ['OMP_NUM_THREADS'] = '1'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
tf.__version__
# Out:
# '2.8.0'

# %%
# !unzip -q /content/Covid_Data_GradientCrescent.zip -d /content/data

# %% [markdown]
# #### Load Image Data

# %%
DATA_LIST = os.listdir('/content/data/Covid_Data_GradientCrescent/two/train')
DATASET_PATH  = '/content/data/Covid_Data_GradientCrescent/two/train'
TEST_DIR =  '/content/data/Covid_Data_GradientCrescent/two/test'
IMAGE_SIZE    = (224, 224)
NUM_CLASSES   = len(DATA_LIST)
BATCH_SIZE    = 10  # try reducing batch size or freeze more layers if your GPU runs out of memory
NUM_EPOCHS    = 40
LEARNING_RATE = 0.0001 # start off with high rate first 0.001 and experiment with reducing it gradually 
DROP_OUT = 0.25

# %% [markdown]
# #### Generate Training and Validation Batches

# %%
train_datagen = ImageDataGenerator(rescale=1./255,rotation_range=50,featurewise_center = True,
                                   featurewise_std_normalization = True,width_shift_range=0.2,
                                   height_shift_range=0.2,shear_range=0.25,zoom_range=0.1,
                                   zca_whitening = True,channel_shift_range = 20,
                                   horizontal_flip = True,vertical_flip = True,
                                   validation_split = 0.2,fill_mode='constant')

train_batches = train_datagen.flow_from_directory(DATASET_PATH,target_size=IMAGE_SIZE,
                                                  shuffle=True,batch_size=BATCH_SIZE,
                                                  subset = "training",seed=42,
                                                  class_mode="binary")

valid_batches = train_datagen.flow_from_directory(DATASET_PATH,target_size=IMAGE_SIZE,
                                                  shuffle=True,batch_size=BATCH_SIZE,
                                                  subset = "validation",seed=42,
                                                  class_mode="binary")
# Out:
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:342: UserWarning: This ImageDataGenerator specifies `zca_whitening` which overrides setting of`featurewise_std_normalization`.
#   warnings.warn('This ImageDataGenerator specifies '
# Found 104 images belonging to 2 classes.
# Found 26 images belonging to 2 classes.

# %% [markdown]
# #### [10 points] Build Model
# Hint: Starting from a pre-trained model typically helps performance on a new task, e.g. starting with weights obtained by training on ImageNet.

# %%
from tensorflow.keras.layers import Flatten, Dense , Dropout
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.optimizers import Adam
import time

# %%
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input
base_model = VGG19(weights="imagenet", include_top=False, input_shape= (224, 224, 3))
base_model.trainable = False ## Not trainable weights

base_model.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %% [markdown]
# ### [5 points] Train Model

# %%
from tensorflow.keras import layers, models
flatten_layer = layers.Flatten()
dense_layer_1 = layers.Dense(256, activation='relu')
#dense_layer_2 = layers.Dense(50, activation='relu')
#dense_layer_3 = layers.Dense(20, activation='relu')
prediction_layer = layers.Dense(1, activation='sigmoid')


model = models.Sequential([
    base_model,
    flatten_layer,
    dense_layer_1,
    #dense_layer_2,
    #dense_layer_3,
    prediction_layer
])

model.compile(
    optimizer='adam',
    loss='BinaryCrossentropy',
    metrics=['accuracy'],
)

history = model.fit(x = train_batches, validation_data = valid_batches , epochs = 40)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:739: UserWarning: This ImageDataGenerator specifies `zca_whitening`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Epoch 1/40
# 11/11 [==============================] - 78s 7s/step - loss: 2.5014 - accuracy: 0.5577 - val_loss: 0.6542 - val_accuracy: 0.5769
# Epoch 2/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.7612 - accuracy: 0.5577 - val_loss: 0.6276 - val_accuracy: 0.5385
# Epoch 3/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.6154 - accuracy: 0.8077 - val_loss: 0.5461 - val_accuracy: 0.8846
# Epoch 4/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.5387 - accuracy: 0.7692 - val_loss: 0.4751 - val_accuracy: 0.9615
# Epoch 5/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.5032 - accuracy: 0.8462 - val_loss: 0.3271 - val_accuracy: 0.9615
# Epoch 6/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.4486 - accuracy: 0.7788 - val_loss: 0.4464 - val_accuracy: 0.6923
# Epoch 7/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.4280 - accuracy: 0.7981 - val_loss: 0.2340 - val_accuracy: 0.9231
# Epoch 8/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.3676 - accuracy: 0.8173 - val_loss: 0.2188 - val_accuracy: 1.0000
# Epoch 9/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.3466 - accuracy: 0.8365 - val_loss: 0.2093 - val_accuracy: 0.9231
# Epoch 10/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.2967 - accuracy: 0.9038 - val_loss: 0.1987 - val_accuracy: 1.0000
# Epoch 11/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.2901 - accuracy: 0.9038 - val_loss: 0.1712 - val_accuracy: 1.0000
# Epoch 12/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.2370 - accuracy: 0.9135 - val_loss: 0.1446 - val_accuracy: 0.9615
# Epoch 13/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.2366 - accuracy: 0.9135 - val_loss: 0.1797 - val_accuracy: 0.9615
# Epoch 14/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.2618 - accuracy: 0.9135 - val_loss: 0.1398 - val_accuracy: 0.9615
# Epoch 15/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.2376 - accuracy: 0.8750 - val_loss: 0.1887 - val_accuracy: 0.9231
# Epoch 16/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.2569 - accuracy: 0.8846 - val_loss: 0.3320 - val_accuracy: 0.7692
# Epoch 17/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.2754 - accuracy: 0.9038 - val_loss: 0.1433 - val_accuracy: 0.9615
# Epoch 18/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.1787 - accuracy: 0.9423 - val_loss: 0.1268 - val_accuracy: 0.9615
# Epoch 19/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.1642 - accuracy: 0.9423 - val_loss: 0.0988 - val_accuracy: 0.9615
# Epoch 20/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.1638 - accuracy: 0.9519 - val_loss: 0.1912 - val_accuracy: 0.9615
# Epoch 21/40
# 11/11 [==============================] - 78s 7s/step - loss: 0.2010 - accuracy: 0.8942 - val_loss: 0.1204 - val_accuracy: 0.9615
# Epoch 22/40
# 11/11 [==============================] - 78s 7s/step - loss: 0.2930 - accuracy: 0.8750 - val_loss: 0.0926 - val_accuracy: 0.9615
# Epoch 23/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.2220 - accuracy: 0.9231 - val_loss: 0.1473 - val_accuracy: 0.9615
# Epoch 24/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.1741 - accuracy: 0.9231 - val_loss: 0.0956 - val_accuracy: 1.0000
# Epoch 25/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.2088 - accuracy: 0.9038 - val_loss: 0.1751 - val_accuracy: 0.9615
# Epoch 26/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.1470 - accuracy: 0.9423 - val_loss: 0.1162 - val_accuracy: 0.9231
# Epoch 27/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.1757 - accuracy: 0.9423 - val_loss: 0.0484 - val_accuracy: 1.0000
# Epoch 28/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.1628 - accuracy: 0.9231 - val_loss: 0.0968 - val_accuracy: 0.9615
# Epoch 29/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.1267 - accuracy: 0.9615 - val_loss: 0.1530 - val_accuracy: 0.9231
# Epoch 30/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.1272 - accuracy: 0.9519 - val_loss: 0.0727 - val_accuracy: 0.9615
# Epoch 31/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.1565 - accuracy: 0.9231 - val_loss: 0.1188 - val_accuracy: 0.9615
# Epoch 32/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.1543 - accuracy: 0.9327 - val_loss: 0.0864 - val_accuracy: 1.0000
# Epoch 33/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.1353 - accuracy: 0.9712 - val_loss: 0.0601 - val_accuracy: 1.0000
# Epoch 34/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.1233 - accuracy: 0.9519 - val_loss: 0.0966 - val_accuracy: 0.9615
# Epoch 35/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.1082 - accuracy: 0.9615 - val_loss: 0.1028 - val_accuracy: 1.0000
# Epoch 36/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.1041 - accuracy: 0.9808 - val_loss: 0.0755 - val_accuracy: 0.9615
# Epoch 37/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.1160 - accuracy: 0.9423 - val_loss: 0.0397 - val_accuracy: 1.0000
# Epoch 38/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.1002 - accuracy: 0.9808 - val_loss: 0.0740 - val_accuracy: 1.0000
# Epoch 39/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.0971 - accuracy: 0.9808 - val_loss: 0.0747 - val_accuracy: 1.0000
# Epoch 40/40
# 11/11 [==============================] - 77s 7s/step - loss: 0.1744 - accuracy: 0.9231 - val_loss: 0.0815 - val_accuracy: 0.9615

# %% [markdown]
# #### [5 points] Plot Accuracy and Loss During Training

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,5))
#plot acc graph
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train_acc')
plt.plot(history.history['val_accuracy'], label='Val_acc')
plt.title("Accuracy over 40 Epochs")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.6, 1])
plt.legend(loc='lower right')
plt.grid(True)

# plot loss graph
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train_loss')
plt.plot(history.history['val_loss'], label = 'Val_loss')
plt.title("Loss over 40 Epochs")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim([0,0.7])
plt.legend(loc='upper right')
plt.grid(True)

# %% [markdown]
# #### Plot Test Results

# %%
import matplotlib.image as mpimg

test_datagen = ImageDataGenerator(rescale=1. / 255)
eval_generator = test_datagen.flow_from_directory(TEST_DIR,target_size=IMAGE_SIZE,
                                                  batch_size=1,shuffle=False,seed=42,class_mode="binary")
eval_generator.reset()
pred = model.predict_generator(eval_generator,18,verbose=1)
for index, probability in enumerate(pred):
    image_path = TEST_DIR + "/" +eval_generator.filenames[index]
    image = mpimg.imread(image_path)
    if image.ndim < 3:
        image = np.reshape(image,(image.shape[0],image.shape[1],1))
        image = np.concatenate([image, image, image], 2)
#         print(image.shape)

    pixels = np.array(image)
    plt.imshow(pixels)
    
    print(eval_generator.filenames[index])
    if probability > 0.5:
        plt.title("%.2f" % (probability[0]*100) + "% Normal")
    else:
        plt.title("%.2f" % ((1-probability[0])*100) + "% COVID19 Pneumonia")
    plt.show()
# Out:
# Found 18 images belonging to 2 classes.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   import sys
# 18/18 [==============================] - 11s 611ms/step
# covid/nejmoa2001191_f3-PA.jpeg
# covid/nejmoa2001191_f4.jpeg
# covid/nejmoa2001191_f5-PA.jpeg
# covid/radiol.2020200490.fig3.jpeg
# covid/ryct.2020200028.fig1a.jpeg
# covid/ryct.2020200034.fig2.jpeg
# covid/ryct.2020200034.fig5-day0.jpeg
# covid/ryct.2020200034.fig5-day4.jpeg
# covid/ryct.2020200034.fig5-day7.jpeg
# normal/NORMAL2-IM-1385-0001.jpeg
# normal/NORMAL2-IM-1396-0001.jpeg
# normal/NORMAL2-IM-1400-0001.jpeg
# normal/NORMAL2-IM-1401-0001.jpeg
# normal/NORMAL2-IM-1406-0001.jpeg
# normal/NORMAL2-IM-1412-0001.jpeg
# normal/NORMAL2-IM-1419-0001.jpeg
# normal/NORMAL2-IM-1422-0001.jpeg
# normal/NORMAL2-IM-1423-0001.jpeg

# %%
#auc in test data set
print(len(eval_generator))
x = model.evaluate_generator(eval_generator,steps = np.ceil(len(eval_generator)),
                           use_multiprocessing = False,verbose = 1,workers=1)
print('Test loss:' , x[0])
print('Test accuracy:',x[1])
# Out:
# Found 18 images belonging to 2 classes.
# 18
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   if __name__ == '__main__':
# 18/18 [==============================] - 11s 615ms/step - loss: 0.0922 - accuracy: 1.0000
# Test loss: 0.09222088009119034
# Test accuracy: 1.0

# %%
y_pred = pred > 0.5

mat = confusion_matrix(eval_generator.classes, y_pred)

print('Confusion Matrix')
target_names = ['Covid', 'Normal']
print(classification_report(eval_generator.classes, y_pred, target_names=target_names))
# Out:
# Confusion Matrix
#               precision    recall  f1-score   support
#
#        Covid       1.00      1.00      1.00         9
#       Normal       1.00      1.00      1.00         9
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18

# %% [markdown]
# ## [10 points] TSNE Plot
# t-Distributed Stochastic Neighbor Embedding (t-SNE) is a widely used technique for dimensionality reduction that is particularly well suited for the visualization of high-dimensional datasets. After training is complete, extract features from a specific deep layer of your choice, use t-SNE to reduce the dimensionality of your extracted features to 2 dimensions and plot the resulting 2D features.

# %%
from sklearn.manifold import TSNE
import seaborn as sns

intermediate_layer_model = Model(inputs=model.input,
                  outputs=model.get_layer('dense_9').output)
tsne_data_generator = test_datagen.flow_from_directory(DATASET_PATH,target_size=IMAGE_SIZE,
                            batch_size=1,shuffle=False,seed=42,class_mode="binary")

vals = intermediate_layer_model.predict(tsne_data_generator)
visual = TSNE(n_components=2).fit_transform(vals)

c = tsne_data_generator.labels
labels = map(lambda x: "COVID-19" if x == 0 else "Normal", tsne_data_generator.labels)
scat=sns.scatterplot(x=visual[:,0],y=visual[:,1], hue=labels, palette=sns.color_palette("hls", 2))
handles,labels = scat.get_legend_handles_labels()
scat.legend(handles, ['Normal', 'COVID-19'])
# Out:
# Found 130 images belonging to 2 classes.
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %% [markdown]
# <!-- ## Task 2: COVID-19 vs Normal vs Tertiary Pneumonia (Bacterial and Viral) -->

# %% [markdown]
# <!-- #### Renew Training Batch and Validation Batch -->

# %% [markdown]
# <!-- #### Renew Model -->
